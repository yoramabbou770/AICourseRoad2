# %% [markdown]
# <a href="https://colab.research.google.com/github/yoramabbou770/AICourseRoad2/blob/main/Task8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import os

# Move to the YOLOv5 directory
# %cd yolov5

# Training command
# !python train.py --img-size 640 --batch-size 16 --epochs 10 --data /content/drive/MyDrive/data.yaml --weights yolov5s.pt --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# 2023-12-30 19:23:02.499315: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-30 19:23:02.499362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-30 19:23:02.500754: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Import necessary libraries
import os

# Move to the YOLOv5 directory
# %cd yolov5

# Training command for different epochs
epoch_sizes = [3, 20, 30]

for epochs in epoch_sizes:
    print(f"Training for {epochs} epochs...")
    # !python train.py --img-size 640 --batch-size 16 --epochs {epochs} --data /content/drive/MyDrive/data.yaml --weights yolov5s.pt --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5/yolov5
# Training for 3 epochs...
# 2023-12-30 21:04:04.094970: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-30 21:04:04.095023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-30 21:04:04.096510: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Import necessary libraries
import os

# Move to the YOLOv5 directory
# %cd yolov5

# Specify the epoch size for the model you want to test
epochs_to_test = 10

# Use either best.pt or last.pt based on your preference
model_path = f"/content/yolov5/runs/train/exp/weights/best.pt"

# Model Testing
output_path = "/content/drive/MyDrive/test_predictions"
os.makedirs(output_path, exist_ok=True)

test_data_path = "/content/drive/MyDrive/test"  # Updated path to the test data

# Run the test command
# !python val.py --img-size 640 --conf 0.001 --data /content/drive/MyDrive/data.yaml --weights {model_path} --save-txt --save-conf --task test --name my_test_results --exist-ok
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5/yolov5
# val: data=/content/drive/MyDrive/data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=True, save_json=False, project=runs/val, name=my_test_results, exist_ok=True, half=False, dnn=False
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/test/data... 500 images, 500 backgrounds, 0 corrupt: 100% 1000/1000 [00:10<00:00, 94.15it/s]
# test: New cache created: /content/drive/MyDrive/test/data.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 32/32 [00:32<00:00,  1.01s/it]
# ...

# %%
# Import necessary libraries
import os

# Move to the YOLOv5 directory
# %cd yolov5/yolov5

# Specify the epoch sizes for the models you want to test
epochs_to_test = [3, 20, 30]

for i, epochs in enumerate(epochs_to_test, start=1):
    print(f"Testing for {epochs} epochs...")

    # Use either best.pt or last.pt based on your preference
    model_path = f"/content/yolov5/yolov5/runs/train/exp{i}/weights/best.pt"

    # Model Testing
    output_path = f"/content/drive/MyDrive/test_predictions/epoch_{epochs}"
    os.makedirs(output_path, exist_ok=True)

    test_data_path = "/content/drive/MyDrive/test"  # Updated path to the test data

    # Run the test command with a specific project and name
    # !python val.py --img-size 640 --conf 0.001 --data /content/drive/MyDrive/data.yaml --weights {model_path} --save-txt --save-conf --task test --project my_test_project --name my_test_results --exist-ok
# Out:
# [Errno 2] No such file or directory: 'yolov5/yolov5'
# /content/yolov5/yolov5
# Testing for 3 epochs...
# val: data=/content/drive/MyDrive/data.yaml, weights=['/content/yolov5/yolov5/runs/train/exp1/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=True, save_json=False, project=my_test_project, name=my_test_results, exist_ok=True, half=False, dnn=False
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/test/data.cache... 500 images, 500 backgrounds, 0 corrupt: 100% 1000/1000 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 32/32 [01:05<00:00,  2.03s/it]
# ...

# %%
import matplotlib.pyplot as plt

# Example data, replace this with your actual results
epochs = [3, 10, 20, 30]
model_results = [0.82, 0.91, 0.94, 0.96]

# Plotting the results
plt.plot(epochs, model_results, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracy')  # You can change this to other metrics like loss
plt.title('Model Performance Over Epochs')

# Show the plot
plt.show()
